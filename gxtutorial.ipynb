# %% [markdown]
# # GX Essentials - Companion Notebook

# %% [markdown]
# This is a blank companion notebook for the course which allows you to write the code from scratch. Please reference **gxtutorial_solutions.ipynb** for the complete code if needed.
#
# **Note:** Any changes made to this notebook will only persist in the Docker container. If you choose to rebuild the Docker container, this notebook will be reset to the default bla

# %% [markdown]
# ### Creating a GX Data Context

# %% [markdown]
# ### Creating a Data Source

# %% [markdown]
# ### Creating a Data Asset

# %% [markdown]
# ### Creating a Batch Definition

# %% [markdown]
# ### Defining Expectations

# %% [markdown]
# ### Running Validations

# %% [markdown]
# ### Using Data Docs

# %% [markdown]
# ### Challenge: Connect & run GX - Solution

# %% [markdown]
# ### Triggering actions with Checkpoints

# %% [markdown]
# ### Root cause analysis of test failures

# %% [markdown]
# ### Creating Fuzzy Expectations

# %% [markdown]
# ### Updating and deleting Expectations in an Expectation Suite

# %% [markdown]
# ### Creating custom Expectations

# %% [markdown]
# **This is the end of the companion notebook. Congratulations for completing the course!**
